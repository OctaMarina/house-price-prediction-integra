# %%
import pandas as pd
import numpy as np
import seaborn as sns
from statsmodels.formula.api import ols

# %%
df = pd.read_csv("../data/subdataset_Biro_Daniel.csv")
df.head()
df.shape
# Out:
# (1168, 15)

# %%
numeric_df = df.select_dtypes(include=['number'])
numeric_df.dropna()
numeric_df
# Out:
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0            250            0              0          0            0
# 1              0           40              0          0            0
# 2            328            0            164          0            0
# 3              0            0            264          0            0
# 4              0            0            242          0            0
# ...          ...          ...            ...        ...          ...
# 1163           0           22              0          0            0
# 1164         431           44              0          0            0
# 1165           0            0              0          0            0
# 1166           0          240              0          0            0
# 1167         143           20              0          0            0
#
#       PoolArea  MiscVal  MoSold  YrSold  SalePrice
# 0            0        0       6    2010     145000
# ...

# %%
sns.pairplot(numeric_df)

# %% [markdown]
# - SalePrice + WoodDeckSF / OpenPorchSF / ScreenPorch - some linearity can be observed, but not enough
# - SalePrice + EnclosedPorch / 3SsnPorch / PoolArea / MiscVal - either non linear or too many items with a value of 0
# - SalePrice + MoSold / YrSold - no linearity, constant values
#
# Conclusion: no variables that can be associated, terminating the regression.
